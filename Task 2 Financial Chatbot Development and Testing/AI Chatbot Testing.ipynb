# %%
import pandas as pd
f1 = pd.read_csv('final_financial_data_report.csv')
f2 = pd.read_csv('final_financial_data_%summary.csv')

# %%
f1
# Out:
#    Unnamed: 0    Company  Year  Total Revenue  Net Income  Total Assets  \
# 0           0  Microsoft  2021         168088       61271        333779
# 1           1  Microsoft  2022         198270       72738        364840
# 2           2  Microsoft  2023         211915       72361        411976
# 3           3      Tesla  2021          53821        5519         62131
# 4           4      Tesla  2022          81462       12556         82338
# 5           5      Tesla  2023          96773       14974        106618
# 6           6      Apple  2021         365817       94680        351002
# 7           7      Apple  2022         394328       99803        352755
# 8           8      Apple  2023         383285       96995        352583
#
#    Total Liabilities  Cash Flow from Operating Activities  Revenue Growth (%)  \
# 0             191791                                76740            0.000000
# 1             198298                                89035           17.956071
# ...

# %%
f2
# Out:
#    Unnamed: 0    Company  Revenue Growth (%)  Net Income Growth (%)  \
# 0           0      Apple            1.664442               0.865772
# 1           1  Microsoft            8.279367               6.065639
# 2           2      Tesla           23.384181              48.920903
#
#    Assets Growth (%)  Liabilities Growth (%)  \
# 0           0.150223                0.355586
# 1           7.408498                2.384083
# 2          20.670475               12.438191
#
#    Cash Flow from Operating Activities Growth (%)
# 0                                        2.635664
# 1                                        4.796563
# 2                                        6.032692

# %%
# %run AI_Financial_chatbot_development.py
# Out:
# ----------------------------------------------------------------------------
#
# Enter start to start the chatbot session; type 'exit' to quit): exit

# %%
# %run AI_Financial_chatbot_development.py
# Out:
# ----------------------------------------------------------------------------
#
# Enter start to start the chatbot session; type 'exit' to quit): start
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
# Enter company name : microsoft
#
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company : 2023
#
# Please enter your query
# What is the total revenue?
# The Total Revenue for Microsoft for fiscal year 2023 is $ 211915
# ----------------------------------------------------------------------------
#
# Enter start to start the chatbot session; type 'exit' to quit): start
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
# Enter company name : tesla
#
# ...

# %%
# %run AI_Financial_chatbot_development.py
# Out:
# ----------------------------------------------------------------------------
#
# Enter start to start the chatbot session; type 'exit' to quit): start
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
# Enter company name : Tesla
#
# The data for the fiscal year 2023, 2022, and 2021 is currently available
# The fiscal year for the selected company : 2022
#
# Please enter your query
# What is the net income growth(%) ?
# The Net Income Growth(%) for Tesla for fiscal year 2022 is 127.505(%)
# ----------------------------------------------------------------------------
#
# Enter start to start the chatbot session; type 'exit' to quit): start
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
# Enter company name : appe
# ...
